# %%
from tensorflow.keras.models import load_model

model = load_model('brain_tumor_model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
from tensorflow.keras.models import load_model
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# Load the trained model
model = load_model('brain_tumor_model.h5')

# Define class labels
class_dict = {
    0: "Glioma Tumor",
    1: "Meninggioma Tumor",
    2: "No Tumor",
    3: "Pituitary"
}

# Prediction function
def predict(img_path):
    label = list(class_dict.values())
    plt.figure(figsize=(12, 12))
    img = Image.open(img_path)
    resized_img = img.resize((299, 299))
    img = np.asarray(resized_img)
    img = np.expand_dims(img, axis=0)
    img = img / 255.0
    predictions = model.predict(img)
    probs = list(predictions[0])
    labels = label
    plt.subplot(2, 1, 1)
    plt.imshow(resized_img)
    plt.axis('off')
    plt.subplot(2, 1, 2)
    bars = plt.barh(labels, probs)
    plt.xlabel('Probability', fontsize=15)
    ax = plt.gca()
    ax.bar_label(bars, fmt='%.2f')
    plt.tight_layout()
    plt.show()

# Use the function
predict(r"C:\Users\dewan\Coding\Python\pythonProject\Cancer_Prediction\Brain Tumor data\Brain Tumor data\Testing\glioma\Te-gl_0011.jpg")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
predict(r"C:\Users\dewan\Coding\Python\pythonProject\Cancer_Prediction\Brain Tumor data\Brain Tumor data\Testing\glioma\Te-gl_0010.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 526ms/step

# %%
predict(r"C:\Users\dewan\Coding\Python\pythonProject\Cancer_Prediction\Brain Tumor data\Brain Tumor data\Testing\notumor\Te-no_0012.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step

# %%
predict(r"C:\Users\dewan\Coding\Python\pythonProject\Cancer_Prediction\Brain Tumor data\Brain Tumor data\Testing\pituitary\Te-pi_0013.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
